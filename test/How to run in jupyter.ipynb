# %%
# !pip install -r rqmnts.txt

# %%
# !python <trainfile>.py #regression_pipeline.py

# %%
# !streamlit run <streamlit_app>.py #Runs the Streamlit script named streamlit_app.py.Uses the default port 8501
#you can access it at:http://localhost:8501 (paste this url in browser while the above statement is executing)

#If port 8501 is already in use, you’ll get an error or Streamlit will fail to start. You can either:Kill the process using port 8501
#using below 2 statements and then execute !streamlit run <streamlit_app>.py

#!netstat -aon | findstr 8501  #check which process is using a specific port (8501 in this case)
#taskkill /PID <PID> /F #kill the process
